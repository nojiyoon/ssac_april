# %% [markdown]
# # 1. Dataset 구축
# ## 1-1. 도커 설치
# 목소리를 녹음하기 위한 프로그램 설치를 위해 도커 설치
# __※ 구글 크롬 사용!__
# - 도커 윈도우용 다운로드:
# https://www.docker.com/products/docker-desktop

# %% [markdown]
# 1) WSL 2 체크
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2) 컴퓨터 다시시작

# %% [markdown]
# 3) 도커 실행
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4) 커널 업데이트
# ![image.png](data:image/png;base64,...)
# - 링크 클릭
# https://docs.microsoft.com/ko-kr/windows/wsl/install-manual#step-4---download-the-linux-kernel-update-package
# - 작업 수행 후 도커 실행
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4) 설정 변경
# - Start Docker Desktop when you log in 체크 해제.
# - apply는 하지마세요...
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5) mimic recording studio 다운
# - https://drive.google.com/file/d/1851i5TmcyrZWDxFtE9XthmawEkA5uLzy/view?usp=sharing
# - 압축 해제
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6) start-windows.bat 설치 및 실행
# - 'start-windows.bat' 더블 클릭
# - 시간 오래 걸림.
# - 중간에 windows 보안 경고 창 엑세스 허용.
# ![image.png](data:image/png;base64,...)
#    - http://localhost:3000/ 접속
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6) 목소리 녹음
# - 마이크 사용 '허용'
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 문장을 평이하고 동일한 속도로 읽음
# - 스페이스바를 누르면 녹음 시작
# - ESC키를 누르면 녹음 종료
# - R키를 이용해 녹음 듣기
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 녹음이 끝나면 웹브라우저 종료
# - 커널 종료(Ctrl+C)
# - 'C:\Users\user\mimic-recording-studio-master\backend\audio_files\'경로에 파일 저장됨
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7) 형식 변환
# - 'C:\Users\user\mimic-recording-studio-master\' 경로로 이동
# - 빈곳에 마우스 커서 위치
# - Shift+마우스 오른쪽 클릭
# - '여기에 PowerShell 창 열기' 클릭
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 도커 실행 중이여야 함
# - PowerShell에 다음 명령어 입력
# docker-compose run --rm backend python generate_ljs_audio_text.py <해시값의폴더이름>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 'C:\Users\user\mimic-recording-studio-master\backend\filelists'에 변환되어 저장됨
# ![image.png](data:image/png;base64,...)
